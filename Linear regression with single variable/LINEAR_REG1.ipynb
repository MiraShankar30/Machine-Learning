# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %% [markdown]
# ### Loading data set

# %%
df=pd.read_csv('C:\\Users\\LENOVO\\Desktop\\Mira_DS\\ML\\1.linear reg\\homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area (sqrt feet)')
plt.ylabel('price ($USD)')
plt.scatter(df.area,df.price,color='red',marker='+')

# %% [markdown]
# ### Create linear regression object

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %% [markdown]
# ### (1) Predict price of a home with area = 3300 sqr ft

# %%
reg.predict([[3300]])
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# m value
# Out:
# array([135.78767123])

# %%
reg.intercept_
#c value
# Out:
# 180616.43835616432

# %%
# %matplotlib inline
plt.xlabel('area (sqrt feet)')
plt.ylabel('price ($USD)')
plt.scatter(df.area,df.price,color='red',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='red')

# %% [markdown]
# ### Generate CSV file with list of home price predictions

# %%
d=pd.read_csv('C:\\Users\\LENOVO\\Desktop\\Mira_DS\\ML\\linear reg\\areas.csv')

# %%
p= reg.predict(d)

# %%
d['prices']=p

# %%
d.to_csv('C:\\Users\\LENOVO\\Desktop\\Mira_DS\\ML\\linear reg\\prediction.csv',index=False)
